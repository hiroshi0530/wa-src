// %%
let a= "hello";
let mut b = "world";
let c = "!";
let d = " ";
let e = "world";
let f = "!";

// %%
let a = String::from("hello");
let mut b = String::from("world");
let c = String::from("!");
println!("{}", a);
// Out:
// hello

// %%
println!("{}", a);
// Out:
// hello

// %%
!rsutc --version
// Out:
// [E0425] Error: cannot find value `rsutc` in this scope
//    ╭─[command_3:1:1]
//    │
//  1 │ !rsutc --version
//    │  ──┬──
//    │    ╰──── not found in this scope
// ───╯
// [E0425] Error: cannot find value `version` in this scope
//    ╭─[command_3:1:1]
//    │
//  1 │ !rsutc --version
//    │          ───┬───
//    │             ╰───── not found in this scope
// ───╯

// %%
#[derive(Debug)]
enum IpAddr {
    V4(u8, u8, u8, u8),
    V6(String),
}

let home = IpAddr::V4(127, 0, 0, 1);

let loopback = IpAddr::V6(String::from("::1"));

// %%
println!("{:?}", home);
// Out:
// V4(127, 0, 0, 1)

// %%
どんなIPアドレスも、バージョン4かバージョン6のどちらかになりますが、同時に両方にはなり得ません。 IPアドレスのその特性により、enumデータ構造が適切なものになります。というのも、 enumの値は、その列挙子のいずれか一つにしかなり得ないからです。


enuｍ は一つの値しか取らない。

// %%
pub fn test() -> i32 {
    12
}

println!("{}", test().to_string());
// Out:
// 12

// %%
コレクションは複数の値を含むことができます。組み込みの配列とタプル型とは異なり、 これらのコレクションが指すデータはヒープに確保され、データ量はコンパイル時にわかる必要はなく、 プログラムの実行にあわせて、伸縮可能であることになります。

コレクションはヒープ領域にメモリが確保され、ランタイム時に利用メモリが確定する。

- ベクタ型（Vec<T>）
- 文字列型（String）
- ハッシュマップ型（HashMap<K, V>）

// %%
let v = vec![1, 2, 3, 4, 5];

// let does_not_exist = &v[100];
// let does_not_exist = v.get(100);
// Out:
// [unused_variables] Error: unused variable: `does_not_exist`
//    ╭─[command_24:1:1]
//    │
//  3 │ let does_not_exist = &v[100];
//    │     ───────┬──────
//    │            ╰──────── warning: unused variable: `does_not_exist`
//    │            │
//    │            ╰──────── help: if this is intentional, prefix it with an underscore: `_does_not_exist`
// ───╯
// [E0597] Error: `v` does not live long enough
//    ╭─[command_24:1:1]
//    │
//  1 │ let v = vec![1, 2, 3, 4, 5];
//    │     ┬
//    │     ╰── binding `v` declared here
//    │
//  4 │ let does_not_exist = v.get(100);
//    │                      ┬────┬────
//    │                      ╰─────────── borrowed value does not live long enough
//    │                           │
//    │                           ╰────── argument requires that `v` is borrowed for `'static`
// ───╯
